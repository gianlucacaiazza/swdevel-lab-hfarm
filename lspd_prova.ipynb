# %% [markdown]
# <a href="https://colab.research.google.com/github/Veronicaa02/swdevel-lab-hfarm/blob/master/lspd_prova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
indicatori_2018 = pd.read_csv('indicatori_2018_it.csv')
indicatori_2019 = pd.read_csv('indicatori_2019_it.csv')
indicatori_2020 = pd.read_csv('indicatori_2020_it.csv')
indicatori_2021 = pd.read_csv('indicatori_2021_it.csv')
indicatori_2022 = pd.read_csv('indicatori_2022_it.csv')
indicatori = pd.concat([indicatori_2018,indicatori_2019,indicatori_2020,indicatori_2021,indicatori_2022], ignore_index=True)
indicatori
# Out:
#       annopubblicazione  corso_codice  \
# 0                  2018           659
# 1                  2018           660
# 2                  2018           868
# 3                  2018           869
# 4                  2018           870
# ...                 ...           ...
# 1837               2022          9262
# 1838               2022          9263
# 1839               2022          9264
# 1840               2022          9265
# 1841               2022          9266
#
#                                       corso_descrizione  p_fuoriregione  \
# 0                                        Giurisprudenza            0.65
# 1                                        Giurisprudenza            0.16
# 2     Economia e marketing nel sistema agro-industriale            0.51
# 3                                    Tecnologie agrarie            0.39
# 4     Scienze del territorio e dell'ambiente agro-fo...            0.44
# ...
